# %% [markdown]
# # Assignment 2 – Anomaly Detection for Cybersecurity Logs
#
# **Student:** Nadav Shapira
# **ID:** 325363505
# **MITRE ATT&CK:** T1078 – Valid Accounts
#
# This notebook presents a fully original anomaly detection project focused on compromised valid accounts.

# %% [markdown]
# ## Dataset
# The dataset simulates login sessions where a small subset represents lateral movement using stolen credentials.

# %% [markdown]
# ## Models
# - Isolation Forest
# - Local Outlier Factor

# %% [markdown]
# ## Visual Results
#
# ### Confusion Matrices
# ![IF](figures/cm_isolation_forest.png)
#
# ![LOF](figures/cm_lof.png)
#
# ### ROC Curve
# ![ROC](figures/roc_comparison.png)
#
# ### PCA Projection
# ![PCA](figures/pca_projection.png)

# %% [markdown]
# ## Conclusion
# The results demonstrate that tree-based and density-based detectors capture different aspects of anomalous login behavior. Isolation Forest showed more stable performance under class imbalance.
